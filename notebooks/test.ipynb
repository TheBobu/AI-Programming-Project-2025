# %%
import sys
import os

print("Python Version:")
print(sys.version)
print("\nPython Executable:")
print(sys.executable)
print("\nCurrent Working Directory:")
print(os.getcwd())
# Out:
# Python Version:
# 3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]
#
# Python Executable:
# c:\Users\andre\.julia\conda\3\x86_64\envs\ai_prog_proj_2025_env\python.exe
#
# Current Working Directory:
# d:\ANDREI\_FACULTATE\MScSem6\AIProg\Repo\AI-Programming-Project-2025\notebooks

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 9.8.0
# ipykernel        : 7.1.0
# ipywidgets       : 8.1.8
# jupyter_client   : 8.7.0
# jupyter_core     : 5.9.1
# jupyter_server   : 2.17.0
# jupyterlab       : 4.5.1
# nbclient         : 0.10.4
# nbconvert        : 7.16.6
# nbformat         : 5.10.4
# notebook         : 7.5.1
# qtconsole        : not installed
# traitlets        : 5.14.3

# %%
import numpy as np

print(f"NumPy version: {np.__version__}")
# Out:
# NumPy version: 2.4.0

# %%
import pandas as pd

print(f"Pandas version: {pd.__version__}")
# Out:
# Pandas version: 2.3.3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print(f"Matplotlib version: {plt.matplotlib.__version__}")
# Out:
# Matplotlib version: 3.10.8
